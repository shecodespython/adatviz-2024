# %% [markdown]
# **Név:** Rafain Emőke
#
# **Szak:** Data Science

# %% [markdown]
# # **BMI fit**
#
# Készítsetek (a saját és a kaggle adatokra is):
#
# * eloszlás (hisztogram) diagramokat:
#   * magasság
#   * testsúly
#   * BMI
# * összefüggés (scatter plot) diagramokat:
#   * magasság vs. testsúly
#   * magasság vs. BMI
#   * testsúly vs. BMI

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sns.set_style("white")
sns.set_palette("tab20")

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (0.6823529411764706, 0.7803921568627451, 0.9098039215686274),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (1.0, 0.7333333333333333, 0.47058823529411764),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.596078431372549, 0.8745098039215686, 0.5411764705882353),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (1.0, 0.596078431372549, 0.5882352941176471),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.7725490196078432, 0.6901960784313725, 0.8352941176470589),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.7686274509803922, 0.611764705882353, 0.5803921568627451),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.9686274509803922, 0.7137254901960784, 0.8235294117647058),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7803921568627451, 0.7803921568627451, 0.7803921568627451),
# ...

# %%
palette = sns.color_palette()

# %%
own = palette[8]
kaggle = palette[18]

fig, axs = plt.subplots(1, 2, figsize=(3.5, 2))

axs[0].add_patch(plt.Rectangle((0, 0), 1, 1, color=own))
axs[0].set_xticks([])
axs[0].set_yticks([])
axs[0].set_xlim(0, 1)
axs[0].set_ylim(0, 1)
axs[0].set_title("Saját Adatok")

axs[1].add_patch(plt.Rectangle((0, 0), 1, 1, color=kaggle))
axs[1].set_xticks([])
axs[1].set_yticks([])
axs[1].set_xlim(0, 1)
axs[1].set_ylim(0, 1)
axs[1].set_title("Kaggle Adatok")

plt.tight_layout()
plt.show()

# %%
url_kaggle = "https://raw.githubusercontent.com/vlewir/adatvizualizacio/refs/heads/main/BMI_fit_kaggle.csv"
url_own = "https://raw.githubusercontent.com/vlewir/adatvizualizacio/refs/heads/main/BMI_fit_own.csv"

df_kaggle = pd.read_csv(url_kaggle)
df_own = pd.read_csv(url_own)

# %% [markdown]
# ## **Saját adatok**

# %%
df_own.head()
# Out:
#    ID  Magassag (m)  Suly (kg)    BMI
# 0   1          1.85         94  27.47
# 1   2          1.60         50  19.53
# 2   3          1.76         65  20.98
# 3   4          1.86        102  29.48
# 4   5          1.89         76  21.28

# %%
df_own.columns
# Out:
# Index(['ID', 'Magassag (m)', 'Suly (kg)', 'BMI'], dtype='object')

# %% [markdown]
# ### **Magasság**

# %%
df_own["Magassag (m)"].describe()
# Out:
# count    22.000000
# mean      1.775000
# std       0.103222
# min       1.580000
# 25%       1.705000
# 50%       1.785000
# 75%       1.850000
# max       1.980000
# Name: Magassag (m), dtype: float64

# %%
fig, ax = plt.subplots()

sns.histplot(data=df_own, x="Magassag (m)", color=palette[8], kde=True, ax=ax)

ax.set_xlabel("Magasság (m)")
ax.set_ylabel("Gyakoriság")
ax.set_title("Magasság Adatok Eloszlása")

ax.spines[["top", "right", "left", "bottom"]].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Testsúly**

# %%
df_own["Suly (kg)"].describe()
# Out:
# count     22.000000
# mean      73.772727
# std       17.438141
# min       48.000000
# 25%       58.500000
# 50%       76.000000
# 75%       86.750000
# max      105.000000
# Name: Suly (kg), dtype: float64

# %%
fig, ax = plt.subplots()

sns.histplot(data=df_own, x="Suly (kg)", color=palette[8], kde=True, ax=ax)

ax.set_xlabel("Súly (kg)")
ax.set_ylabel("Gyakoriság")
ax.set_title("Súly Adatok Eloszlása")

ax.spines[["top", "right", "left", "bottom"]].set_visible(False)

plt.tight_layout()
plt.show()

# %%
df_own["BMI"].describe()
# Out:
# count    22.000000
# mean     23.117273
# std       3.573302
# min      16.710000
# 25%      20.815000
# 50%      22.955000
# 75%      26.020000
# max      29.480000
# Name: BMI, dtype: float64

# %% [markdown]
# ### **BMI**

# %%
fig, ax = plt.subplots()

sns.histplot(data=df_own, x="BMI", color=palette[8], kde=True, ax=ax)

ax.set_xlabel("BMI")
ax.set_ylabel("Gyakoriság")
ax.set_title("BMI Adatok Eloszlása")

ax.spines[["top", "right", "left", "bottom"]].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Magasság vs. Súly**

# %%
fig, ax = plt.subplots()

sns.regplot(data=df_own, x="Magassag (m)", y="Suly (kg)", color=palette[8], scatter=True, ax=ax)

ax.set_xlabel("Magasság (m)")
ax.set_ylabel("Súly (kg)")
ax.set_title("Magasság vs. Súly")

ax.spines[["top", "right", "left", "bottom"]].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Magasság vs. BMI**

# %%
fig, ax = plt.subplots()

sns.regplot(data=df_own, x="Magassag (m)", y="BMI", color=palette[8], scatter=True, ax=ax)

ax.set_xlabel("Magasság (m)")
ax.set_ylabel("BMI")
ax.set_title("Magasság vs. BMI")

ax.spines[["top", "right", "left", "bottom"]].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Súly vs. BMI**

# %%
fig, ax = plt.subplots()

sns.regplot(data=df_own, x="Suly (kg)", y="BMI", color=palette[8], scatter=True, ax=ax)

ax.set_xlabel("Súly (kg)")
ax.set_ylabel("BMI")
ax.set_title("Súly vs. BMI")

ax.spines[["top", "right", "left", "bottom"]].set_visible(False)

plt.tight_layout()
plt.show()

# %%
df_own.columns
# Out:
# Index(['ID', 'Magassag (m)', 'Suly (kg)', 'BMI'], dtype='object')

# %% [markdown]
# ## **Kaggle adatok**

# %%
df_kaggle.head()
# Out:
#    ID  Magassag (m)  Suly (kg)    BMI
# 0   1          1.74         96  31.71
# 1   2          1.89         87  24.36
# 2   3          1.85        110  32.14
# 3   4          1.95        104  27.35
# 4   5          1.49         61  27.48

# %%
df_kaggle.columns
# Out:
# Index(['ID', 'Magassag (m)', 'Suly (kg)', 'BMI'], dtype='object')

# %% [markdown]
# ### **Magasság**

# %%
df_kaggle["Magassag (m)"].describe()
# Out:
# count    500.000000
# mean       1.699440
# std        0.163753
# min        1.400000
# 25%        1.560000
# 50%        1.705000
# 75%        1.840000
# max        1.990000
# Name: Magassag (m), dtype: float64

# %%
fig, ax = plt.subplots()

sns.histplot(data=df_kaggle, x="Magassag (m)", color=palette[18], kde=True, ax=ax)

ax.set_xlabel("Magasság (m)")
ax.set_ylabel("Gyakoriság")
ax.set_title("Magasság Adatok Eloszlása")

ax.spines[["top", "right", "left", "bottom"]].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Testsúly**

# %%
df_kaggle["Suly (kg)"].describe()
# Out:
# count    500.000000
# mean     106.000000
# std       32.382607
# min       50.000000
# 25%       80.000000
# 50%      106.000000
# 75%      136.000000
# max      160.000000
# Name: Suly (kg), dtype: float64

# %%
fig, ax = plt.subplots()

sns.histplot(data=df_kaggle, x="Suly (kg)", color=palette[18], kde=True, ax=ax)

ax.set_xlabel("Súly (kg)")
ax.set_ylabel("Gyakoriság")
ax.set_title("Súly Adatok Eloszlása")

ax.spines[["top", "right", "left", "bottom"]].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **BMI**

# %%
df_kaggle["BMI"].describe()
# Out:
# count    500.00000
# mean      37.76572
# std       13.96555
# min       12.75000
# 25%       27.16750
# 50%       36.95500
# 75%       46.38750
# max       78.85000
# Name: BMI, dtype: float64

# %%
fig, ax = plt.subplots()

sns.histplot(data=df_kaggle, x="BMI", color=palette[18], kde=True, ax=ax)

ax.set_xlabel("BMI")
ax.set_ylabel("Gyakoriság")
ax.set_title("BMI Adatok Eloszlása")

ax.spines[["top", "right", "left", "bottom"]].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Magasság vs. Súly**

# %%
fig, ax = plt.subplots()

sns.regplot(data=df_kaggle, x="Magassag (m)", y="Suly (kg)", color=palette[18], scatter=True, ax=ax)

ax.set_xlabel("Magasság (m)")
ax.set_ylabel("Súly (kg)")
ax.set_title("Magasság vs. Súly")

ax.spines[["top", "right", "left", "bottom"]].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Magasság vs. BMI**

# %%
fig, ax = plt.subplots()

sns.regplot(data=df_kaggle, x="Magassag (m)", y="BMI", color=palette[18], scatter=True, ax=ax)

ax.set_xlabel("Magasság (m)")
ax.set_ylabel("BMI")
ax.set_title("Magasság vs. BMI")

ax.spines[["top", "right", "left", "bottom"]].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Súly vs. BMI**

# %%
fig, ax = plt.subplots()

sns.regplot(data=df_kaggle, x="Suly (kg)", y="BMI", color=palette[18], scatter=True, ax=ax)

ax.set_xlabel("Súly (kg)")
ax.set_ylabel("BMI")
ax.set_title("Súly vs. BMI")

ax.spines[["top", "right", "left", "bottom"]].set_visible(False)

plt.tight_layout()
plt.show()
